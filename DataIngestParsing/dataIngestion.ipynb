# %%
import langchain

# %% [markdown]
# ### DATA Ingestion phase Understanding
#
# Data ingestion is the process of collecting, importing, and moving raw data from various sources into a centralized system

# %%
import os
from langchain_core.documents import Document

# %%
import sys
print(sys.executable)
# Out:
# /home/chirag/Desktop/Projects/RAG/RAG-Basics/.venv/bin/python

# %%
import torch
print(torch.__file__)
print(torch.__version__)
# Out:
# /home/chirag/Desktop/Projects/RAG/RAG-Basics/.venv/lib/python3.12/site-packages/torch/__init__.py
# 2.12.1+cu130

# %% [markdown]
# ## Document Structure in langchain ##

# %%
doc = Document(page_content="THis is the main content that is searched",
               metadata={
                   "source":"random.txt",
                   "author":"Chirag Tiwari",
                   "Page_no":"1"
               })

print("Document Structure COntent:")
print(f"Page_Content : {doc.page_content}")
print(f"MetaData : {doc.metadata}")
# Out:
# Document Structure COntent:
# Page_Content : THis is the main content that is searched
# MetaData : {'source': 'random.txt', 'author': 'Chirag Tiwari', 'Page_no': '1'}

# %%
os.makedirs('data/text_files',exist_ok=True)

# %%
text_content = {
    "data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
"data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """
}

for path,content in text_content.items():
    with open(path,'w',encoding="utf-8") as f:
        f.write(content)

print("Sample text files created....")
# Out:
# Sample text files created....

# %% [markdown]
# ### TextLoader : Single file reader

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("data/text_files/python_intro.txt",encoding="utf-8")

documents = loader.load()

print(documents[0])
# Out:
# page_content='Python Programming Introduction
#
# Python is a high-level, interpreted programming language known for its simplicity and readability.
# Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
# programming languages in the world.
#
# Key Features:
# - Easy to learn and use
# - Extensive standard library
# - Cross-platform compatibility
# - Strong community support
#
# Python is widely used in web development, data science, artificial intelligence, and automation.' metadata={'source': 'data/text_files/python_intro.txt'}

# %%
from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(path="data/text_files",glob="**/*",show_progress=True, loader_cls=TextLoader)

doc_content = dir_loader.load()

# print(f"Total number of files:{len(doc_content)} ")
# print(doc_content)
# print(doc_content[0])
# print(doc_content[1])

# enumerate() is a built-in Python function that lets you loop through an iterable while keeping track of the index. Instead of manually creating and updating a counter,

for index, doc in enumerate(doc_content):
    print(f'\n Document: {index+1}')
    print(f"Source: {doc.metadata['source']}")
    print(f"Length : {len(doc.page_content)} characters")
    print(f"\n  Content: {doc.page_content}")
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 1435.18it/s]
#  Document: 1
# Source: data/text_files/machine_learning.txt
# Length : 575 characters
#
#   Content: Machine Learning Basics
#
# Machine learning is a subset of artificial intelligence that enables systems to learn and improve
# from experience without being explicitly programmed. It focuses on developing computer programs
# that can access data and use it to learn for themselves.
#
# Types of Machine Learning:
# 1. Supervised Learning: Learning with labeled data
# 2. Unsupervised Learning: Finding patterns in unlabeled data
# 3. Reinforcement Learning: Learning through rewards and penalties
#
# Applications include image recognition, speech processing, and recommendation systems
#
#
#
#
#  Document: 2
# Source: data/text_files/python_intro.txt
# Length : 489 characters
#
#   Content: Python Programming Introduction
#
# Python is a high-level, interpreted programming language known for its simplicity and readability.
# ...
